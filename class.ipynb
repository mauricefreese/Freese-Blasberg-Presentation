# %% [markdown]
# # Panda's for tables and non-data parsing

# %% [raw]
# Make text ITALIC: *Italic*
# Make text BOLD: **Bold**
# List item as a bullet: dash and space -
# List item as a number: Simple as number and dot 1.
# Indenting text: Greater than and space >
# Inline code span: Back quotation mark " ` "
# Block of code: Triple back quotation marks " ``` "
# Link a section: [Title of Section](#title-of-section)
# Hyperlink: [Text](URL)

# %% [markdown]
# https://stackabuse.com/reading-and-writing-html-tables-with-pandas/
# https://realpython.com/python-csv/

# %% [markdown]
# Using HTML, one of the standard languages in web development, we are going to look at the native `<table>` element. In this presentation, we are going to look at reading dataframes using pandas with HTML data from a URL and then from a file and then we are going to write a dataframes using HTML style.

# %% [markdown]
# ## Making a Table from a URL

# %% [markdown]
# *    Title: Reading and Writing HTML Tables with Pandas
# *    Author: Naazneen Jatu
# *    Date: Last Updated: September 19th, 2021
# *    Code version: Python 3.x
# *    Availability: https://stackabuse.com/reading-and-writing-html-tables-with-pandas

# %%
import pandas as pd

# %% [markdown]
# In order to read the HTML `<table>` element from a website and turn it into a dataframe in Pandas, we will need to use a familiar Pandas function to read the html URL. As we remember when working with [CSV files](https://realpython.com/python-csv/), they had functions `pd.read_csv()` and `pd.to_csv()`. In this case we will use `pd.read_html()` and `pd.to_html()` to manipulate our data frames.

# %% [markdown]
# The data used in the presentation today is the Defensive Stats per team for the 2021 season from [The National Football League](https://www.nfl.com/stats/team-stats/defense/passing/2021/reg/all).

# %%
# credit given above
table = pd.read_html('https://www.nfl.com/stats/team-stats/defense/passing/2021/reg/all')
print('Tables Recovered:', len(table)) # Confirm what we see with output
df = table[0] # This will save the first recovered table as df
print(df.head()) # Prints the first five rows
# Out:
# Tables Recovered: 1
#                    Team  Att  Cmp  Cmp %  Yds/Att   Yds  TD  INT  1st  1st%  \
# 0  BuccaneersBuccaneers  680  445   65.4      6.0  4062  26   17  214  31.5
# 1          ChiefsChiefs  610  401   65.7      7.0  4273  27   15  209  34.3
# 2      ChargersChargers  559  357   63.9      6.7  3761  27   11  199  35.6
# 3      SteelersSteelers  563  355   63.1      6.5  3656  24   13  186  33.0
# 4            BillsBills  530  297   56.0      5.2  2771  12   19  138  26.0
#
#    Sck
# 0   47
# 1   31
# 2   35
# 3   55
# 4   42

# %%
print(df.head(10)) # This prints the first ten rows
# Out:
#                    Team  Att  Cmp  Cmp %  Yds/Att   Yds  TD  INT  1st  1st%  \
# 0  BuccaneersBuccaneers  680  445   65.4      6.0  4062  26   17  214  31.5
# 1          ChiefsChiefs  610  401   65.7      7.0  4273  27   15  209  34.3
# 2      ChargersChargers  559  357   63.9      6.7  3761  27   11  199  35.6
# 3      SteelersSteelers  563  355   63.1      6.5  3656  24   13  186  33.0
# 4            BillsBills  530  297   56.0      5.2  2771  12   19  138  26.0
# 5        CowboysCowboys  612  364   59.5      6.6  4049  24   26  191  31.2
# 6        RaidersRaiders  606  400   66.0      6.2  3789  29    6  202  33.3
# 7      DolphinsDolphins  608  373   61.4      6.4  3871  23   14  199  32.7
# 8          RavensRavens  621  397   63.9      7.6  4742  31    9  232  37.4
# 9              RamsRams  625  416   66.6      6.6  4109  17   19  214  34.2
#
#    Sck
# 0   47
# 1   31
# 2   35
# 3   55
# 4   42
# 5   41
# 6   35
# 7   48
# 8   34
# 9   50

# %% [markdown]
# But we can replace this with any number that is equal to or less than our index of total rows. So if we ask Pandas to print more than the amount of rows, it will just print the number of rows in the table.

# %% [markdown]
# https://www.nfl.com/stats/team-stats/defense/passing/2021/reg/all

# %%
# It is easy now export to a csv file to use in a project
dfto_csv = df.to_csv('2021NFL_Defense.csv',encoding='utf-8', sep=',')

# %% [markdown]
# ## Making a Table from a HTML File

# %% [markdown]
# In order to make a dataframe from an HTML file I am going to goto the Chrome inspect and copy the table elements and make it into a HTML file.

# %% [markdown]
# First we need download a python library to read the HTML, so we pip install [LXML](https://lxml.de/)

# %%
# ! pip install lxml

# %% [markdown]
# Then we need to copy source code from the browsers 'inspect' in the developer tools and I am going to find the table element and copy it to VSCODE (my code-editor of choice) and going to save it as a html. You can make your own table in html using this [layout](https://www.w3schools.com/html/html_tables.asp)... TAKE NOTE OF THIS LINK.

# %%
table2 = pd.read_html('2021NFL_Defense.html')
print('Tables Recovered:', len(table2)) # Confirm what we see with out output
df_file = table2[0] # This will save the first recovered table as df
print(df_file.head(32)) # Prints the first five rows
# Out:
# Tables Recovered: 2
#              Team  Att  Cmp  Cmp %  Yds/Att   Yds  TD  INT  1st  1st%  Sck
# 0           49ers  545  372   68.3      6.4  3510  25    9  180  33.0   48
# 1           Bears  477  314   65.8      6.8  3257  31    8  170  35.6   49
# 2         Bengals  626  420   67.1      6.7  4222  26   13  213  34.0   42
# 3           Bills  530  297   56.0      5.2  2771  12   19  138  26.0   42
# 4         Broncos  562  341   60.7      6.5  3652  22   13  192  34.2   36
# 5          Browns  576  367   63.7      6.0  3439  29   13  184  31.9   43
# 6      Buccaneers  680  445   65.4      6.0  4062  26   17  214  31.5   47
# 7       Cardinals  561  367   65.4      6.5  3645  30   13  192  34.2   41
# 8        Chargers  559  357   63.9      6.7  3761  27   11  199  35.6   35
# 9          Chiefs  610  401   65.7      7.0  4273  27   15  209  34.3   31
# 10          Colts  597  390   65.3      6.7  3980  32   19  213  35.7   33
# 11        Cowboys  612  364   59.5      6.6  4049  24   26  191  31.2   41
# 12       Dolphins  608  373   61.4      6.4  3871  23   14  199  32.7   48
# 13         Eagles  589  409   69.4      6.4  3756  28   12  208  35.3   29
# 14        Falcons  577  391   67.8      6.8  3952  31   12  214  37.1   18
# 15  Football Team  597  400   67.0      7.3  4333  34   11  220  36.8   38
# 16         Giants  611  402   65.8      6.3  3839  27   15  216  35.4   34
# 17        Jaguars  543  377   69.4      7.1  3875  24    7  198  36.5   32
# 18           Jets  587  401   68.3      7.5  4409  28    7  234  39.9   33
# 19          Lions  544  359   66.0      7.6  4160  31   11  211  38.8   30
# 20        Packers  603  379   62.8      6.2  3724  31   18  194  32.2   39
# 21       Panthers  515  337   65.4      6.3  3266  26    9  170  33.0   39
# 22       Patriots  538  319   59.3      5.9  3181  21   23  176  32.7   36
# 23        Raiders  606  400   66.0      6.2  3789  29    6  202  33.3   35
# 24           Rams  625  416   66.6      6.6  4109  17   19  214  34.2   50
# 25         Ravens  621  397   63.9      7.6  4742  31    9  232  37.4   34
# 26         Saints  592  369   62.3      6.4  3821  20   18  185  31.2   46
# 27       Seahawks  658  443   67.3      6.9  4513  24   11  240  36.5   34
# 28       Steelers  563  355   63.1      6.5  3656  24   13  186  33.0   55
# 29         Texans  546  363   66.5      7.5  4117  27   17  218  39.9   32
# 30         Titans  628  395   62.9      6.6  4169  24   16  204  32.5   43
# 31        Vikings  626  401   64.1      6.9  4300  29   16  224  35.8   51

# %% [markdown]
# As you see above the amount of tables recovered is two compared to one in the first one. Due to the html element being embedded with a lot of source code for NFL teams logos, as seen if you click on the html file that is attached. If you wanted to dig through the source code and get rid of all the fancy CSS and formatting in the source code from the site then you an dig threw it and you'd just get the basic table.

# %% [markdown]
# ### Practice One

# %% [markdown]
# Since we just made this HTML table from a HTML file and converted it to a dataframe in Pandas, I am going to need your help in saving it as a CSV.

# %%
df_filecsv= df.to_csv('HTML2021NFL_Defense.csv',encoding='utf-8', sep=',')  # solution

# %% [markdown]
# ## Writing a HTML table in Pandas

# %% [markdown]
# Lets say that we want to look at how often a team's defence was thrown on with a completion and the amount interceptions they earned from these passing attempts.

# %%
df_write = pd.DataFrame({"Teams":["49ers", "Bears", "Bengals", "Bills", "Broncos"], 
                         "Passing Att":[545,477,626,530,562], 
                         "Cmp Pct":[68.3,65.8,67.1,56.0,60.7], 
                         "INT":[9,8,13,19,13]})
df_write.to_html('write2021NFL_Defense.html', index=False)

# %%
table3 = pd.read_html('write2021NFL_Defense.html')
print('Tables Recovered:', len(table3)) # Confirm what we see with out output
df_wtest = table3[0] # This will save the first recovered table as df
print(df_wtest.head(20))
# Out:
# Tables Recovered: 1
#      Teams  Passing Att  Cmp Pct  INT
# 0    49ers          545     68.3    9
# 1    Bears          477     65.8    8
# 2  Bengals          626     67.1   13
# 3    Bills          530     56.0   19
# 4  Broncos          562     60.7   13

# %% [markdown]
# df.style is a command used to assist with the modification of the styler object
#     this controls the visual of the dataframe found from the web

# %% [markdown]
# ### Highlighting Maximum & Minimum Values
#     .highlight_max() will highlight th maximum value in a given table
# highlighting minimum values is very similar and simple and can be done by using the command .highlight_min()
#
# ### Heat Maps
#     Heat maps are a visual add on that allows you to organize your data with color shades. The darker the color, the higher the value
#     Although there is no direct c0mmand to complete this task, the styler.background_gradient() seems to do the trick
#         text_color_threshold: dicates the text visibility within the colored graph
# ### Set properties method
#    we can use the command set_properties command to set data indepednadnt properties
#     This is used purely for visual appeal and its pretty easy to sustomize your table

# %% [markdown]
# ### Decimals
#     A table with the least amount of decimals possible is more pleasing to the eye and easier to understand
#     The .set_percision() command is used to determine the maximum number of decimals allowed
#     Add easy example...
#     Now the dataframe is much easier to read
# ### Titles
#     When you would like to title your table, just use the .set_caption() command

# %% [markdown]
# ### Rows
#     If you would like to customize the number of rowns your table consists of you can use pd.set_option("max rows() command
#     This will allow you to add and take away rows as needed.

# %% [markdown]
# Simple dataframe example that we will be altering

# %%
df5 = df.head(5)
df5.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_05a0d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Team</th>
#       <th class="col_heading level0 col1" >Att</th>
#       <th class="col_heading level0 col2" >Cmp</th>
#       <th class="col_heading level0 col3" >Cmp %</th>
#       <th class="col_heading level0 col4" >Yds/Att</th>
#       <th class="col_heading level0 col5" >Yds</th>
#       <th class="col_heading level0 col6" >TD</th>
#       <th class="col_heading level0 col7" >INT</th>
#       <th class="col_heading level0 col8" >1st</th>
#       <th class="col_heading level0 col9" >1st%</th>
#       <th class="col_heading level0 col10" >Sck</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_05a0d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_05a0d_row0_col0" class="data row0 col0" >BuccaneersBuccaneers</td>
#       <td id="T_05a0d_row0_col1" class="data row0 col1" >680</td>
#       <td id="T_05a0d_row0_col2" class="data row0 col2" >445</td>
#       <td id="T_05a0d_row0_col3" class="data row0 col3" >65.400000</td>
#       <td id="T_05a0d_row0_col4" class="data row0 col4" >6.000000</td>
#       <td id="T_05a0d_row0_col5" class="data row0 col5" >4062</td>
#       <td id="T_05a0d_row0_col6" class="data row0 col6" >26</td>
#       <td id="T_05a0d_row0_col7" class="data row0 col7" >17</td>
#       <td id="T_05a0d_row0_col8" class="data row0 col8" >214</td>
#       <td id="T_05a0d_row0_col9" class="data row0 col9" >31.500000</td>
#       <td id="T_05a0d_row0_col10" class="data row0 col10" >47</td>
#     </tr>
#     <tr>
#       <th id="T_05a0d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_05a0d_row1_col0" class="data row1 col0" >ChiefsChiefs</td>
#       <td id="T_05a0d_row1_col1" class="data row1 col1" >610</td>
#       <td id="T_05a0d_row1_col2" class="data row1 col2" >401</td>
#       <td id="T_05a0d_row1_col3" class="data row1 col3" >65.700000</td>
#       <td id="T_05a0d_row1_col4" class="data row1 col4" >7.000000</td>
#       <td id="T_05a0d_row1_col5" class="data row1 col5" >4273</td>
#       <td id="T_05a0d_row1_col6" class="data row1 col6" >27</td>
#       <td id="T_05a0d_row1_col7" class="data row1 col7" >15</td>
#       <td id="T_05a0d_row1_col8" class="data row1 col8" >209</td>
#       <td id="T_05a0d_row1_col9" class="data row1 col9" >34.300000</td>
#       <td id="T_05a0d_row1_col10" class="data row1 col10" >31</td>
#     </tr>
#     <tr>
#       <th id="T_05a0d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_05a0d_row2_col0" class="data row2 col0" >ChargersChargers</td>
#       <td id="T_05a0d_row2_col1" class="data row2 col1" >559</td>
#       <td id="T_05a0d_row2_col2" class="data row2 col2" >357</td>
#       <td id="T_05a0d_row2_col3" class="data row2 col3" >63.900000</td>
#       <td id="T_05a0d_row2_col4" class="data row2 col4" >6.700000</td>
#       <td id="T_05a0d_row2_col5" class="data row2 col5" >3761</td>
#       <td id="T_05a0d_row2_col6" class="data row2 col6" >27</td>
#       <td id="T_05a0d_row2_col7" class="data row2 col7" >11</td>
#       <td id="T_05a0d_row2_col8" class="data row2 col8" >199</td>
#       <td id="T_05a0d_row2_col9" class="data row2 col9" >35.600000</td>
#       <td id="T_05a0d_row2_col10" class="data row2 col10" >35</td>
#     </tr>
#     <tr>
#       <th id="T_05a0d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_05a0d_row3_col0" class="data row3 col0" >SteelersSteelers</td>
#       <td id="T_05a0d_row3_col1" class="data row3 col1" >563</td>
#       <td id="T_05a0d_row3_col2" class="data row3 col2" >355</td>
#       <td id="T_05a0d_row3_col3" class="data row3 col3" >63.100000</td>
#       <td id="T_05a0d_row3_col4" class="data row3 col4" >6.500000</td>
#       <td id="T_05a0d_row3_col5" class="data row3 col5" >3656</td>
#       <td id="T_05a0d_row3_col6" class="data row3 col6" >24</td>
#       <td id="T_05a0d_row3_col7" class="data row3 col7" >13</td>
#       <td id="T_05a0d_row3_col8" class="data row3 col8" >186</td>
#       <td id="T_05a0d_row3_col9" class="data row3 col9" >33.000000</td>
#       <td id="T_05a0d_row3_col10" class="data row3 col10" >55</td>
#     </tr>
#     <tr>
#       <th id="T_05a0d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_05a0d_row4_col0" class="data row4 col0" >BillsBills</td>
#       <td id="T_05a0d_row4_col1" class="data row4 col1" >530</td>
#       <td id="T_05a0d_row4_col2" class="data row4 col2" >297</td>
#       <td id="T_05a0d_row4_col3" class="data row4 col3" >56.000000</td>
#       <td id="T_05a0d_row4_col4" class="data row4 col4" >5.200000</td>
#       <td id="T_05a0d_row4_col5" class="data row4 col5" >2771</td>
#       <td id="T_05a0d_row4_col6" class="data row4 col6" >12</td>
#       <td id="T_05a0d_row4_col7" class="data row4 col7" >19</td>
#       <td id="T_05a0d_row4_col8" class="data row4 col8" >138</td>
#       <td id="T_05a0d_row4_col9" class="data row4 col9" >26.000000</td>
#       <td id="T_05a0d_row4_col10" class="data row4 col10" >42</td>
#     </tr>
#   </tbody>
# </table>

# %%
df6 = df.style.set_precision(2) # here we limit the decimal places to 2 decimal places

df6
# Out:
# /var/folders/vb/1w4hk2k9619cmfw7pmwzxkh80000gn/T/ipykernel_38286/833940573.py:1: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   df6 = df.style.set_precision(2) # here we limit the decimal places to 2 decimal places
# <style type="text/css">
# </style>
# <table id="T_1b3c6_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Team</th>
#       <th class="col_heading level0 col1" >Att</th>
#       <th class="col_heading level0 col2" >Cmp</th>
#       <th class="col_heading level0 col3" >Cmp %</th>
#       <th class="col_heading level0 col4" >Yds/Att</th>
#       <th class="col_heading level0 col5" >Yds</th>
#       <th class="col_heading level0 col6" >TD</th>
#       <th class="col_heading level0 col7" >INT</th>
#       <th class="col_heading level0 col8" >1st</th>
#       <th class="col_heading level0 col9" >1st%</th>
#       <th class="col_heading level0 col10" >Sck</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1b3c6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1b3c6_row0_col0" class="data row0 col0" >BuccaneersBuccaneers</td>
#       <td id="T_1b3c6_row0_col1" class="data row0 col1" >680</td>
#       <td id="T_1b3c6_row0_col2" class="data row0 col2" >445</td>
#       <td id="T_1b3c6_row0_col3" class="data row0 col3" >65.40</td>
#       <td id="T_1b3c6_row0_col4" class="data row0 col4" >6.00</td>
#       <td id="T_1b3c6_row0_col5" class="data row0 col5" >4062</td>
#       <td id="T_1b3c6_row0_col6" class="data row0 col6" >26</td>
#       <td id="T_1b3c6_row0_col7" class="data row0 col7" >17</td>
#       <td id="T_1b3c6_row0_col8" class="data row0 col8" >214</td>
#       <td id="T_1b3c6_row0_col9" class="data row0 col9" >31.50</td>
#       <td id="T_1b3c6_row0_col10" class="data row0 col10" >47</td>
#     </tr>
#     <tr>
#       <th id="T_1b3c6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1b3c6_row1_col0" class="data row1 col0" >ChiefsChiefs</td>
#       <td id="T_1b3c6_row1_col1" class="data row1 col1" >610</td>
#       <td id="T_1b3c6_row1_col2" class="data row1 col2" >401</td>
#       <td id="T_1b3c6_row1_col3" class="data row1 col3" >65.70</td>
#       <td id="T_1b3c6_row1_col4" class="data row1 col4" >7.00</td>
#       <td id="T_1b3c6_row1_col5" class="data row1 col5" >4273</td>
#       <td id="T_1b3c6_row1_col6" class="data row1 col6" >27</td>
#       <td id="T_1b3c6_row1_col7" class="data row1 col7" >15</td>
#       <td id="T_1b3c6_row1_col8" class="data row1 col8" >209</td>
#       <td id="T_1b3c6_row1_col9" class="data row1 col9" >34.30</td>
#       <td id="T_1b3c6_row1_col10" class="data row1 col10" >31</td>
#     </tr>
#     <tr>
#       <th id="T_1b3c6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1b3c6_row2_col0" class="data row2 col0" >ChargersChargers</td>
#       <td id="T_1b3c6_row2_col1" class="data row2 col1" >559</td>
#       <td id="T_1b3c6_row2_col2" class="data row2 col2" >357</td>
#       <td id="T_1b3c6_row2_col3" class="data row2 col3" >63.90</td>
#       <td id="T_1b3c6_row2_col4" class="data row2 col4" >6.70</td>
#       <td id="T_1b3c6_row2_col5" class="data row2 col5" >3761</td>
#       <td id="T_1b3c6_row2_col6" class="data row2 col6" >27</td>
#       <td id="T_1b3c6_row2_col7" class="data row2 col7" >11</td>
#       <td id="T_1b3c6_row2_col8" class="data row2 col8" >199</td>
#       <td id="T_1b3c6_row2_col9" class="data row2 col9" >35.60</td>
#       <td id="T_1b3c6_row2_col10" class="data row2 col10" >35</td>
#     </tr>
#     <tr>
#       <th id="T_1b3c6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1b3c6_row3_col0" class="data row3 col0" >SteelersSteelers</td>
#       <td id="T_1b3c6_row3_col1" class="data row3 col1" >563</td>
#       <td id="T_1b3c6_row3_col2" class="data row3 col2" >355</td>
#       <td id="T_1b3c6_row3_col3" class="data row3 col3" >63.10</td>
#       <td id="T_1b3c6_row3_col4" class="data row3 col4" >6.50</td>
#       <td id="T_1b3c6_row3_col5" class="data row3 col5" >3656</td>
#       <td id="T_1b3c6_row3_col6" class="data row3 col6" >24</td>
#       <td id="T_1b3c6_row3_col7" class="data row3 col7" >13</td>
#       <td id="T_1b3c6_row3_col8" class="data row3 col8" >186</td>
#       <td id="T_1b3c6_row3_col9" class="data row3 col9" >33.00</td>
#       <td id="T_1b3c6_row3_col10" class="data row3 col10" >55</td>
#     </tr>
#     <tr>
#       <th id="T_1b3c6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1b3c6_row4_col0" class="data row4 col0" >BillsBills</td>
#       <td id="T_1b3c6_row4_col1" class="data row4 col1" >530</td>
#       <td id="T_1b3c6_row4_col2" class="data row4 col2" >297</td>
#       <td id="T_1b3c6_row4_col3" class="data row4 col3" >56.00</td>
#       <td id="T_1b3c6_row4_col4" class="data row4 col4" >5.20</td>
#       <td id="T_1b3c6_row4_col5" class="data row4 col5" >2771</td>
#       <td id="T_1b3c6_row4_col6" class="data row4 col6" >12</td>
#       <td id="T_1b3c6_row4_col7" class="data row4 col7" >19</td>
#       <td id="T_1b3c6_row4_col8" class="data row4 col8" >138</td>
#       <td id="T_1b3c6_row4_col9" class="data row4 col9" >26.00</td>
#       <td id="T_1b3c6_row4_col10" class="data row4 col10" >42</td>
#     </tr>
#     <tr>
#       <th id="T_1b3c6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1b3c6_row5_col0" class="data row5 col0" >CowboysCowboys</td>
#       <td id="T_1b3c6_row5_col1" class="data row5 col1" >612</td>
#       <td id="T_1b3c6_row5_col2" class="data row5 col2" >364</td>
#       <td id="T_1b3c6_row5_col3" class="data row5 col3" >59.50</td>
#       <td id="T_1b3c6_row5_col4" class="data row5 col4" >6.60</td>
#       <td id="T_1b3c6_row5_col5" class="data row5 col5" >4049</td>
#       <td id="T_1b3c6_row5_col6" class="data row5 col6" >24</td>
#       <td id="T_1b3c6_row5_col7" class="data row5 col7" >26</td>
#       <td id="T_1b3c6_row5_col8" class="data row5 col8" >191</td>
#       <td id="T_1b3c6_row5_col9" class="data row5 col9" >31.20</td>
#       <td id="T_1b3c6_row5_col10" class="data row5 col10" >41</td>
#     </tr>
#     <tr>
#       <th id="T_1b3c6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1b3c6_row6_col0" class="data row6 col0" >RaidersRaiders</td>
#       <td id="T_1b3c6_row6_col1" class="data row6 col1" >606</td>
#       <td id="T_1b3c6_row6_col2" class="data row6 col2" >400</td>
#       <td id="T_1b3c6_row6_col3" class="data row6 col3" >66.00</td>
#       <td id="T_1b3c6_row6_col4" class="data row6 col4" >6.20</td>
#       <td id="T_1b3c6_row6_col5" class="data row6 col5" >3789</td>
#       <td id="T_1b3c6_row6_col6" class="data row6 col6" >29</td>
#       <td id="T_1b3c6_row6_col7" class="data row6 col7" >6</td>
#       <td id="T_1b3c6_row6_col8" class="data row6 col8" >202</td>
#       <td id="T_1b3c6_row6_col9" class="data row6 col9" >33.30</td>
#       <td id="T_1b3c6_row6_col10" class="data row6 col10" >35</td>
#     </tr>
#     <tr>
#       <th id="T_1b3c6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1b3c6_row7_col0" class="data row7 col0" >DolphinsDolphins</td>
#       <td id="T_1b3c6_row7_col1" class="data row7 col1" >608</td>
#       <td id="T_1b3c6_row7_col2" class="data row7 col2" >373</td>
#       <td id="T_1b3c6_row7_col3" class="data row7 col3" >61.40</td>
#       <td id="T_1b3c6_row7_col4" class="data row7 col4" >6.40</td>
#       <td id="T_1b3c6_row7_col5" class="data row7 col5" >3871</td>
#       <td id="T_1b3c6_row7_col6" class="data row7 col6" >23</td>
#       <td id="T_1b3c6_row7_col7" class="data row7 col7" >14</td>
#       <td id="T_1b3c6_row7_col8" class="data row7 col8" >199</td>
#       <td id="T_1b3c6_row7_col9" class="data row7 col9" >32.70</td>
#       <td id="T_1b3c6_row7_col10" class="data row7 col10" >48</td>
#     </tr>
#     <tr>
#       <th id="T_1b3c6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1b3c6_row8_col0" class="data row8 col0" >RavensRavens</td>
#       <td id="T_1b3c6_row8_col1" class="data row8 col1" >621</td>
#       <td id="T_1b3c6_row8_col2" class="data row8 col2" >397</td>
#       <td id="T_1b3c6_row8_col3" class="data row8 col3" >63.90</td>
#       <td id="T_1b3c6_row8_col4" class="data row8 col4" >7.60</td>
#       <td id="T_1b3c6_row8_col5" class="data row8 col5" >4742</td>
#       <td id="T_1b3c6_row8_col6" class="data row8 col6" >31</td>
#       <td id="T_1b3c

# %% [markdown]
# As said before we can highlight minimum and maximum values if needed

# %%
def highlight_max(s):
    '''
    highlight the maximum in a Series yellow.
    '''
    is_max = s == s.max()
    return ['background-color: red' if v else '' for v in is_max]

# %%
df.style.apply(highlight_max)
# Out:
# <style type="text/css">
# #T_5b0f0_row0_col1, #T_5b0f0_row0_col2, #T_5b0f0_row3_col10, #T_5b0f0_row5_col7, #T_5b0f0_row8_col4, #T_5b0f0_row8_col5, #T_5b0f0_row10_col3, #T_5b0f0_row11_col0, #T_5b0f0_row12_col9, #T_5b0f0_row14_col4, #T_5b0f0_row20_col6, #T_5b0f0_row21_col9, #T_5b0f0_row30_col8, #T_5b0f0_row31_col3 {
#   background-color: red;
# }
# </style>
# <table id="T_5b0f0_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Team</th>
#       <th class="col_heading level0 col1" >Att</th>
#       <th class="col_heading level0 col2" >Cmp</th>
#       <th class="col_heading level0 col3" >Cmp %</th>
#       <th class="col_heading level0 col4" >Yds/Att</th>
#       <th class="col_heading level0 col5" >Yds</th>
#       <th class="col_heading level0 col6" >TD</th>
#       <th class="col_heading level0 col7" >INT</th>
#       <th class="col_heading level0 col8" >1st</th>
#       <th class="col_heading level0 col9" >1st%</th>
#       <th class="col_heading level0 col10" >Sck</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b0f0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5b0f0_row0_col0" class="data row0 col0" >BuccaneersBuccaneers</td>
#       <td id="T_5b0f0_row0_col1" class="data row0 col1" >680</td>
#       <td id="T_5b0f0_row0_col2" class="data row0 col2" >445</td>
#       <td id="T_5b0f0_row0_col3" class="data row0 col3" >65.400000</td>
#       <td id="T_5b0f0_row0_col4" class="data row0 col4" >6.000000</td>
#       <td id="T_5b0f0_row0_col5" class="data row0 col5" >4062</td>
#       <td id="T_5b0f0_row0_col6" class="data row0 col6" >26</td>
#       <td id="T_5b0f0_row0_col7" class="data row0 col7" >17</td>
#       <td id="T_5b0f0_row0_col8" class="data row0 col8" >214</td>
#       <td id="T_5b0f0_row0_col9" class="data row0 col9" >31.500000</td>
#       <td id="T_5b0f0_row0_col10" class="data row0 col10" >47</td>
#     </tr>
#     <tr>
#       <th id="T_5b0f0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5b0f0_row1_col0" class="data row1 col0" >ChiefsChiefs</td>
#       <td id="T_5b0f0_row1_col1" class="data row1 col1" >610</td>
#       <td id="T_5b0f0_row1_col2" class="data row1 col2" >401</td>
#       <td id="T_5b0f0_row1_col3" class="data row1 col3" >65.700000</td>
#       <td id="T_5b0f0_row1_col4" class="data row1 col4" >7.000000</td>
#       <td id="T_5b0f0_row1_col5" class="data row1 col5" >4273</td>
#       <td id="T_5b0f0_row1_col6" class="data row1 col6" >27</td>
#       <td id="T_5b0f0_row1_col7" class="data row1 col7" >15</td>
#       <td id="T_5b0f0_row1_col8" class="data row1 col8" >209</td>
#       <td id="T_5b0f0_row1_col9" class="data row1 col9" >34.300000</td>
#       <td id="T_5b0f0_row1_col10" class="data row1 col10" >31</td>
#     </tr>
#     <tr>
#       <th id="T_5b0f0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5b0f0_row2_col0" class="data row2 col0" >ChargersChargers</td>
#       <td id="T_5b0f0_row2_col1" class="data row2 col1" >559</td>
#       <td id="T_5b0f0_row2_col2" class="data row2 col2" >357</td>
#       <td id="T_5b0f0_row2_col3" class="data row2 col3" >63.900000</td>
#       <td id="T_5b0f0_row2_col4" class="data row2 col4" >6.700000</td>
#       <td id="T_5b0f0_row2_col5" class="data row2 col5" >3761</td>
#       <td id="T_5b0f0_row2_col6" class="data row2 col6" >27</td>
#       <td id="T_5b0f0_row2_col7" class="data row2 col7" >11</td>
#       <td id="T_5b0f0_row2_col8" class="data row2 col8" >199</td>
#       <td id="T_5b0f0_row2_col9" class="data row2 col9" >35.600000</td>
#       <td id="T_5b0f0_row2_col10" class="data row2 col10" >35</td>
#     </tr>
#     <tr>
#       <th id="T_5b0f0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5b0f0_row3_col0" class="data row3 col0" >SteelersSteelers</td>
#       <td id="T_5b0f0_row3_col1" class="data row3 col1" >563</td>
#       <td id="T_5b0f0_row3_col2" class="data row3 col2" >355</td>
#       <td id="T_5b0f0_row3_col3" class="data row3 col3" >63.100000</td>
#       <td id="T_5b0f0_row3_col4" class="data row3 col4" >6.500000</td>
#       <td id="T_5b0f0_row3_col5" class="data row3 col5" >3656</td>
#       <td id="T_5b0f0_row3_col6" class="data row3 col6" >24</td>
#       <td id="T_5b0f0_row3_col7" class="data row3 col7" >13</td>
#       <td id="T_5b0f0_row3_col8" class="data row3 col8" >186</td>
#       <td id="T_5b0f0_row3_col9" class="data row3 col9" >33.000000</td>
#       <td id="T_5b0f0_row3_col10" class="data row3 col10" >55</td>
#     </tr>
#     <tr>
#       <th id="T_5b0f0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5b0f0_row4_col0" class="data row4 col0" >BillsBills</td>
#       <td id="T_5b0f0_row4_col1" class="data row4 col1" >530</td>
#       <td id="T_5b0f0_row4_col2" class="data row4 col2" >297</td>
#       <td id="T_5b0f0_row4_col3" class="data row4 col3" >56.000000</td>
#       <td id="T_5b0f0_row4_col4" class="data row4 col4" >5.200000</td>
#       <td id="T_5b0f0_row4_col5" class="data row4 col5" >2771</td>
#       <td id="T_5b0f0_row4_col6" class="data row4 col6" >12</td>
#       <td id="T_5b0f0_row4_col7" class="data row4 col7" >19</td>
#       <td id="T_5b0f0_row4_col8" class="data row4 col8" >138</td>
#       <td id="T_5b0f0_row4_col9" class="data row4 col9" >26.000000</td>
#       <td id="T_5b0f0_row4_col10" class="data row4 col10" >42</td>
#     </tr>
#     <tr>
#       <th id="T_5b0f0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5b0f0_row5_col0" class="data row5 col0" >CowboysCowboys</td>
#       <td id="T_5b0f0_row5_col1" class="data row5 col1" >612</td>
#       <td id="T_5b0f0_row5_col2" class="data row5 col2" >364</td>
#       <td id="T_5b0f0_row5_col3" class="data row5 col3" >59.500000</td>
#       <td id="T_5b0f0_row5_col4" class="data row5 col4" >6.600000</td>
#       <td id="T_5b0f0_row5_col5" class="data row5 col5" >4049</td>
#       <td id="T_5b0f0_row5_col6" class="data row5 col6" >24</td>
#       <td id="T_5b0f0_row5_col7" class="data row5 col7" >26</td>
#       <td id="T_5b0f0_row5_col8" class="data row5 col8" >191</td>
#       <td id="T_5b0f0_row5_col9" class="data row5 col9" >31.200000</td>
#       <td id="T_5b0f0_row5_col10" class="data row5 col10" >41</td>
#     </tr>
#     <tr>
#       <th id="T_5b0f0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5b0f0_row6_col0" class="data row6 col0" >RaidersRaiders</td>
#       <td id="T_5b0f0_row6_col1" class="data row6 col1" >606</td>
#       <td id="T_5b0f0_row6_col2" class="data row6 col2" >400</td>
#       <td id="T_5b0f0_row6_col3" class="data row6 col3" >66.000000</td>
#       <td id="T_5b0f0_row6_col4" class="data row6 col4" >6.200000</td>
#       <td id="T_5b0f0_row6_col5" class="data row6 col5" >3789</td>
#       <td id="T_5b0f0_row6_col6" class="data row6 col6" >29</td>
#       <td id="T_5b0f0_row6_col7" class="data row6 col7" >6</td>
#       <td id="T_5b0f0_row6_col8" class="data row6 col8" >202</td>
#       <td id="T_5b0f0_row6_col9" class="data row6 col9" >33.300000</td>
#       <td id="T_5b0f0_row6_col10" class="data row6 col10" >35</td>
#     </tr>
#     <tr>
#       <th id="T_5b0f0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5b0f0_row7_col0" class="data row7 col0" >DolphinsDolphins</td>
#       <td id="T_5b0f0_row7_col1" class="data row7 col1" >608</td>
#       <td id="T_5b0f0_row7_col2" class="data row7 col2" >373</td>
#       <td id="T_5b0f0_row7_col3" class="data row7 col3" >61.400000</td>
#       <td id="T_5b0f0_row7_col4" class="data row7 col4" >6.400000</td>
#       <td id="T_5b0f0_row7_col5" class="data row7 col5" >3871</td>
#       <td id="T_5b0f0_row7_col6" class="data row7 col6" >23</td>
#       <td id="T_5b0f0_row7_col7" class="data row7 col7" >14</td>
#       <td id="T_5b0f0_row7_col8" class="data row7 col8" >199</td>
#       <td id="T_5b0f0_row7_col9" class="data row7 col9" >32.700000</td>
#       <td id="T_5b0f0_row7_col10" class="data row7 col10" >48</td>
#     </tr>
#     <tr>
#       <th id="T_5b0f0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5b0f0_row8_col0" class="data row8 col0" >RavensRavens</td>

# %% [markdown]
# Shown above is highlighting the maxmim values of each row
#     Next, we can build on what we have by combining the two

# %%
Seen here, we have all maxmimum values highlighted
Lets say you want to only highlight the maximum value in the entire table 
We can use the .apply function to indicate we want to be testing the entire table
# Out:
#   Input In [85]
#     Seen here, we have all maxmimum values highlighted while all negative values are marked red
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# Reference: https://pandas.pydata.org/pandas-docs/version/1.1/user_guide/style.html

# %%
import seaborn as sns

cm = sns.light_palette('blue', as_cmap=True)

df8 = df6.style.background_gradient(cmap=cm)
df8
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [96], in <cell line: 5>()
#       1 import seaborn as sns
#       3 cm = sns.light_palette('blue', as_cmap=True)
# ----> 5 df8 = df6.style.background_gradient(cmap=cm)
#       6 df8
#
# AttributeError: 'Styler' object has no attribute 'style'

# %%
commands:
    - remove column
    - remove row
